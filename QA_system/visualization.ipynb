# %%
with open("loss.log") as f:
    lines = f.readlines()

loss = []
for i in lines:
    loss.append(float(i.strip().split(" ")[-1]))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
plt.ylim((0, 20))
plt.plot(loss)
